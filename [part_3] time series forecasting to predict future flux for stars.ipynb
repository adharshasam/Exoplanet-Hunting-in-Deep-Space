# %% [markdown]
# ***Importing data***

# %%
import pandas as pd
exoTrain = pd.read_csv("exoTrain.csv")

exoTrain["LABEL"] = exoTrain["LABEL"].replace(1, 0)
exoTrain["LABEL"] = exoTrain["LABEL"].replace(2, 1)

exoTrain['star_id'] = range(1, len(exoTrain) + 1)
exoTrain['star_id'] = exoTrain['star_id'].astype('str')

# %% [markdown]
# ***TIME SERIES FORECASTING USING FACEBOOK'S PROPHET MODEL*** 🔮

# %% [markdown]
# *A statistical method of analyzing historical time data to make predictions on future values based on previous observations.*

# %% [markdown]
# ***Data preparation for training our model***

# %%
exoTrain_T = exoTrain.T 

#naming the column names as star ids and deleting the id row from data frame
exoTrain_T.columns = exoTrain_T.iloc[3198]
exoTrain_T.drop(exoTrain_T.tail(1).index,inplace=True) 
print(exoTrain_T.tail(5))
#exoTrain_T.head(5)
# Out:
# star_id        1      2      3      4       5      6      7       8      9  \
# FLUX.3193  92.54   0.76   5.06 -12.67 -438.54  19.27  -0.44    95.3   4.53
# FLUX.3194  39.32  -11.7  -11.8  -8.77 -399.71  -43.9   10.9   48.86  21.95
# FLUX.3195  61.42   6.46 -28.91 -17.31 -384.65 -41.63 -11.77  -10.62  26.94
# FLUX.3196   5.08   16.0 -70.02 -17.35 -411.79  -52.9  -9.25 -112.02  34.08
# FLUX.3197 -39.54  19.93 -96.67  13.98 -510.54 -16.16 -36.69 -229.92  44.65
#
# star_id         10  ...    5078   5079    5080   5081   5082    5083    5084  \
# FLUX.3193  3162.53  ...  210.09   8.75  163.02  28.82 -74.95  151.75 -136.16
# FLUX.3194  3398.28  ...     3.8 -10.69   86.29 -20.12 -46.29  -24.45   38.03
# FLUX.3195  3648.34  ...   16.33  -9.54   13.06 -14.41  -3.08   -17.0  100.28
# FLUX.3196  3671.97  ...   27.35  -2.48  161.22 -43.35 -28.43    3.23  -45.64
# FLUX.3197  3781.91  ...    21.3  -8.69   213.6 -30.04 -48.68   19.28   35.58
#
# star_id     5085   5086   5087
# FLUX.3193  -3.47   -1.5 -25.33
# FLUX.3194  65.73  -4.65 -41.31
# FLUX.3195  88.42 -14.55 -16.72
# FLUX.3196  79.07  -6.41 -14.09
# FLUX.3197  79.43  -2.55  27.82
#
# [5 rows x 5087 columns]

# %%
exoTrain_T.columns = exoTrain_T.columns.astype(str)
exoTrain_T.columns = exoTrain_T.columns.str.replace('.0', '')
exoTrain_T.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
# star_id      1      2       3       4        5       6      7       8       9  \
# LABEL        1      1       1       1        1       1      1       1       1
# FLUX.1   93.85 -38.88  532.64  326.52 -1107.21   211.1   9.34  238.77 -103.54
# FLUX.2   83.81 -33.83  535.92  347.39 -1112.59  163.57  49.96  262.16 -118.97
# FLUX.3    20.1 -58.54  513.73  302.35 -1118.95  179.16   33.3   277.8 -108.93
# FLUX.4  -26.98 -40.09  496.92  298.13  -1095.1  187.82   9.63  190.16  -72.25
#
# star_id          ...      78     79             81      82     83      84  \
# LABEL         1  ...       0      0       0      0       0      0       0
# FLUX.1  -265.91  ...  125.57   7.45  475.61 -46.63  299.41 -91.91  989.75
# FLUX.2  -318.59  ...   78.69  10.02   395.5 -55.39  302.77 -92.97  891.01
# FLUX.3  -335.66  ...   98.29   6.87  423.61 -64.88  278.68 -78.76  908.53
# FLUX.4  -450.47  ...   91.16  -2.82  376.36 -88.75  263.48 -97.33  851.83
#
# star_id      85    86      87
# LABEL         0     0       0
# FLUX.1   273.39  3.82  323.28
# FLUX.2    278.0  2.09  306.36
# FLUX.3   261.73 -3.29  293.16
# FLUX.4   236.99 -2.88  287.67
#
# [5 rows x 5087 columns]

# %%
exoTrain_T.drop(exoTrain_T.head(1).index,inplace=True)
exoTrain_T.head(5)
# Out:
# star_id      1      2       3       4        5       6      7       8       9  \
# FLUX.1   93.85 -38.88  532.64  326.52 -1107.21   211.1   9.34  238.77 -103.54
# FLUX.2   83.81 -33.83  535.92  347.39 -1112.59  163.57  49.96  262.16 -118.97
# FLUX.3    20.1 -58.54  513.73  302.35 -1118.95  179.16   33.3   277.8 -108.93
# FLUX.4  -26.98 -40.09  496.92  298.13  -1095.1  187.82   9.63  190.16  -72.25
# FLUX.5  -39.56 -79.31  456.45  317.74 -1057.55  188.46  37.64  180.98  -61.46
#
# star_id          ...      78     79             81      82     83      84  \
# FLUX.1  -265.91  ...  125.57   7.45  475.61 -46.63  299.41 -91.91  989.75
# FLUX.2  -318.59  ...   78.69  10.02   395.5 -55.39  302.77 -92.97  891.01
# FLUX.3  -335.66  ...   98.29   6.87  423.61 -64.88  278.68 -78.76  908.53
# FLUX.4  -450.47  ...   91.16  -2.82  376.36 -88.75  263.48 -97.33  851.83
# FLUX.5  -453.09  ...   78.42  -1.56  338.94  -75.4  236.89  -68.0  755.11
#
# star_id      85    86      87
# FLUX.1   273.39  3.82  323.28
# FLUX.2    278.0  2.09  306.36
# FLUX.3   261.73 -3.29  293.16
# FLUX.4   236.99 -2.88  287.67
# FLUX.5   280.73  1.66  249.89
#
# [5 rows x 5087 columns]

# %% [markdown]
# In order for our prophet forecasting model to work, the dataframe must contain *ds* and *y* columns containing date and values respectively.
#
# But, our ds column contains string entries.
#
# `ParserError: Unknown string format: FLUX.1`
#
# Hence, for the purpose of training our model for our data, we convert this column entries to arbitrary datetime values.
#
# They can be translated to FLUX values later on.

# %% [markdown]
# *The datasets were prepared late-summer 2016.*
#
# So, we create a new column of dates starting from August 15, 2016 to replace the flux entries for the purpose of fitting the data in our time-series forecasting model.

# %%
exoTrain_T['date'] = pd.date_range(start='15/08/2016', periods=len(exoTrain_T), freq='D')
#exoTrain_T.head(5)
exoTrain_T.tail(5)
# Out:
# star_id        1      2      3      4       5      6      7       8      9  \
# FLUX.3193  92.54   0.76   5.06 -12.67 -438.54  19.27  -0.44    95.3   4.53
# FLUX.3194  39.32  -11.7  -11.8  -8.77 -399.71  -43.9   10.9   48.86  21.95
# FLUX.3195  61.42   6.46 -28.91 -17.31 -384.65 -41.63 -11.77  -10.62  26.94
# FLUX.3196   5.08   16.0 -70.02 -17.35 -411.79  -52.9  -9.25 -112.02  34.08
# FLUX.3197 -39.54  19.93 -96.67  13.98 -510.54 -16.16 -36.69 -229.92  44.65
#
# star_id             ...     79             81     82      83      84     85  \
# FLUX.3193  3162.53  ...   8.75  163.02  28.82 -74.95  151.75 -136.16  -3.47
# FLUX.3194  3398.28  ... -10.69   86.29 -20.12 -46.29  -24.45   38.03  65.73
# FLUX.3195  3648.34  ...  -9.54   13.06 -14.41  -3.08   -17.0  100.28  88.42
# FLUX.3196  3671.97  ...  -2.48  161.22 -43.35 -28.43    3.23  -45.64  79.07
# FLUX.3197  3781.91  ...  -8.69   213.6 -30.04 -48.68   19.28   35.58  79.43
#
# star_id       86     87       date
# FLUX.3193   -1.5 -25.33 2025-05-12
# FLUX.3194  -4.65 -41.31 2025-05-13
# FLUX.3195 -14.55 -16.72 2025-05-14
# FLUX.3196  -6.41 -14.09 2025-05-15
# FLUX.3197  -2.55  27.82 2025-05-16
#
# [5 rows x 5088 columns]

# %%
#exoTrain_T = exoTrain_T.reset_index()

df = pd.melt(exoTrain_T, id_vars = 'date', value_vars = exoTrain_T.iloc[:,0:5087])
df.columns = ['ds', 'star_id', 'y'] #df.columns = ['time_point', 'star_id', 'light_intensity']
df.tail(3198) #checking if we have all the flux entries
# Out:
#                  ds star_id      y
# 16259941 2025-05-16    4998  -6.27
# 16259942 2016-08-15    4999 -26.68
# 16259943 2016-08-16    4999 -22.69
# 16259944 2016-08-17    4999 -20.56
# 16259945 2016-08-18    4999 -26.62
# ...             ...     ...    ...
# 16263134 2025-05-12    4999 -42.82
# 16263135 2025-05-13    4999   3.46
# 16263136 2025-05-14    4999  11.78
# 16263137 2025-05-15    4999   3.45
# 16263138 2025-05-16    4999   2.01
#
# [3198 rows x 3 columns]

# %%
len(df['star_id'].unique())
# Out:
# 3750

# %%
df.shape
# Out:
# (16263139, 3)

# %% [markdown]
# After transforming the data from the wide format to the long format, we have 16263139 records.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16263139 entries, 0 to 16263138
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   ds       datetime64[ns]
#  1   star_id  object
#  2   y        object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 372.2+ MB

# %% [markdown]
# Next, we group the pandas dataframe by the column *star_id* and save it in a new dataframe called *groups_by_star_id*.

# %%
#group data by star_id
groups_by_star_id = df.groupby('star_id')

#check groups in the dataframe
len(groups_by_star_id.groups.keys())
# Out:
# 3750

# %% [markdown]
# ***Writing a function to train and forecast each group***

# %% [markdown]
# After predicting the future dataframe, Prophet produces a long list of outputs.
#
# We only kept ds, yhat, yhat_lower and yhat_upper.
#
# *   yhat is the predicted value.
#
# *   yhat_lower and yhat_upper are the lower and upper bound of the uncertainty interval.

# %%
from prophet import Prophet

def train_and_forecast(group):

  #initiate the model
  m = Prophet()

  #fit the model
  m.fit(group)

  #make predictions
  future = m.make_future_dataframe(periods = 15) #period=15 means that the function predicts the next 15 light intensity values for each star_id.
  forecast = m.predict(future)[['ds', 'yhat', 'yhat_lower', 'yhat_upper']] #  forecast = m.predict(future)[['time_point', 'yhat', 'yhat_lower', 'yhat_upper']]
  forecast['star_id'] = group['star_id'].iloc[0]

  #return forecasted results
  return forecast[['ds', 'star_id', 'yhat', 'yhat_upper', 'yhat_lower']]

# %% [markdown]
# ***Multiple time series forecasting using for-loop***

# %% [markdown]
# ```
# star_id_list = (df["star_id"].unique()).tolist()
#
# #create an empty dataframe
# for_loop_forecast = pd.DataFrame()
#
# #loop through each star_id
# for star_id in star_id_list:
#   #get the data for each star_id
#   group = groups_by_star_id.get_group(star_id)
#   #make forecast
#   forecast = train_and_forecast(group)
#   #add forecast results to the dataframe
#   for_loop_forecast = pd.concat((for_loop_forecast, forecast))
#
# for_loop_forecast.head(5)
# ```

# %% [markdown]
# Performing multiple time series forecasting by for-looping was taking an eternity 👵🏻
#
# So, we use Python's `mutiprocessing` package to run the forecasts in parallel.

# %% [markdown]
# ***Multiple time series forecasting using Multi-Processing***

# %%
import multiprocessing

#get time series data for each star_id and save in a list
series = [groups_by_star_id.get_group(star_id) for star_id in star_id_list]

#create a pool process with the number of worker processes being the number of CPUs
from multiprocessing import Pool
import os
p = Pool(os.cpu_count())

#make predictions for each star_id and save the result to a list
from tqdm import tqdm
import time
predictions = list(tqdm(p.imap(train_and_forecast, series), total=len(series)))

#terminate the pool process
p.close()

#tell the pool to wait till all the jobs are finished before exit
p.join()

#concatenate results
multiprocess_forecast = pd.concat(predictions)
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/1hgca_5v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94100', 'data', 'file=/tmp/tmp5oal43fk/ovs_c0ok.json', 'init=/tmp/tmp5oal43fk/1hgca_5v.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelx9fbnpul/prophet_model-20221015095758.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:57:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3250/3750 [2:33:56<16:55,  2.03s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/6558k6uk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/5w3bcc1l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61807', 'data', 'file=/tmp/tmp5oal43fk/6558k6uk.json', 'init=/tmp/tmp5oal43fk/5w3bcc1l.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model0fe_khzv/prophet_model-20221015095800.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3251/3750 [2:33:58<17:15,  2.07s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/j6cqv82t.json
# 09:58:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/hj0yjgmm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88334', 'data', 'file=/tmp/tmp5oal43fk/j6cqv82t.json', 'init=/tmp/tmp5oal43fk/hj0yjgmm.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelkv6ez8ej/prophet_model-20221015095802.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3252/3750 [2:34:01<19:04,  2.30s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/o58icc65.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/pin56daw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74006', 'data', 'file=/tmp/tmp5oal43fk/o58icc65.json', 'init=/tmp/tmp5oal43fk/pin56daw.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeljg6i1iir/prophet_model-20221015095805.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3253/3750 [2:34:02<16:52,  2.04s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/2sjnvyjo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/p_5e_0mw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30515', 'data', 'file=/tmp/tmp5oal43fk/2sjnvyjo.json', 'init=/tmp/tmp5oal43fk/p_5e_0mw.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeldlky47l8/prophet_model-20221015095807.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3254/3750 [2:34:05<19:05,  2.31s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/1_cm4r71.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/84y1eaal.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77133', 'data', 'file=/tmp/tmp5oal43fk/1_cm4r71.json', 'init=/tmp/tmp5oal43fk/84y1eaal.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelm67iog78/prophet_model-20221015095810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3255/3750 [2:34:06<16:08,  1.96s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/8y65tz_y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/7_0twgtl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23973', 'data', 'file=/tmp/tmp5oal43fk/8y65tz_y.json', 'init=/tmp/tmp5oal43fk/7_0twgtl.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelmipxjisc/prophet_model-20221015095811.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3256/3750 [2:34:09<19:26,  2.36s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/xovmddyd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/bge71fsi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84021', 'data', 'file=/tmp/tmp5oal43fk/xovmddyd.json', 'init=/tmp/tmp5oal43fk/bge71fsi.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelbw0coplt/prophet_model-20221015095814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3257/3750 [2:34:11<17:36,  2.14s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 09:58:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/qm_j0yia.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/g910qiux.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17576', 'data', 'file=/tmp/tmp5oal43fk/qm_j0yia.json', 'init=/tmp/tmp5oal43fk/g910qiux.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelk39thbh4/prophet_model-20221015095816.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3258/3750 [2:34:14<19:20,  2.36s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/3t_8qwor.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/hhd271ws.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79668', 'data', 'file=/tmp/tmp5oal43fk/3t_8qwor.json', 'init=/tmp/tmp5oal43fk/hhd271ws.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelxb5jnfzc/prophet_model-20221015095818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3259/3750 [2:34:15<16:02,  1.96s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/zwh96_1y.json
# 09:58:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/cdg5oc8s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25365', 'data', 'file=/tmp/tmp5oal43fk/zwh96_1y.json', 'init=/tmp/tmp5oal43fk/cdg5oc8s.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelg0vyvr09/prophet_model-20221015095819.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3260/3750 [2:34:18<17:37,  2.16s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/eg7egb96.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/pylk04h6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1242', 'data', 'file=/tmp/tmp5oal43fk/eg7egb96.json', 'init=/tmp/tmp5oal43fk/pylk04h6.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelidv_oruz/prophet_model-20221015095822.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3261/3750 [2:34:19<16:12,  1.99s/it]09:58:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/14_ps25g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/z8rq6cm5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53908', 'data', 'file=/tmp/tmp5oal43fk/14_ps25g.json', 'init=/tmp/tmp5oal43fk/z8rq6cm5.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeluphmvg01/prophet_model-20221015095824.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3262/3750 [2:34:22<18:21,  2.26s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/508tlye6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/b7_aevac.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2660', 'data', 'file=/tmp/tmp5oal43fk/508tlye6.json', 'init=/tmp/tmp5oal43fk/b7_aevac.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelwl5oju5f/prophet_model-20221015095826.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3263/3750 [2:34:23<15:11,  1.87s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/otnu9gbl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/rm7d7w1p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26967', 'data', 'file=/tmp/tmp5oal43fk/otnu9gbl.json', 'init=/tmp/tmp5oal43fk/rm7d7w1p.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelf_56mdf7/prophet_model-20221015095827.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3264/3750 [2:34:27<19:26,  2.40s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/w8oot6yj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/vz_3eol_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47912', 'data', 'file=/tmp/tmp5oal43fk/w8oot6yj.json', 'init=/tmp/tmp5oal43fk/vz_3eol_.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelvn4y1nqy/prophet_model-20221015095831.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3265/3750 [2:34:27<14:37,  1.81s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/s7gkh40k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/ecb1c3da.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27207', 'data', 'file=/tmp/tmp5oal43fk/s7gkh40k.json', 'init=/tmp/tmp5oal43fk/ecb1c3da.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model91a979bf/prophet_model-20221015095832.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3266/3750 [2:34:30<17:35,  2.18s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/dkivn8sf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/v8q9mus2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61185', 'data', 'file=/tmp/tmp5oal43fk/dkivn8sf.json', 'init=/tmp/tmp5oal43fk/v8q9mus2.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelctxhhadw/prophet_model-20221015095835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3267/3750 [2:34:31<14:28,  1.80s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/uoapbg4g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/o3hwvsba.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24101', 'data', 'file=/tmp/tmp5oal43fk/uoapbg4g.json', 'init=/tmp/tmp5oal43fk/o3hwvsba.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelpqa5uq39/prophet_model-20221015095836.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3268/3750 [2:34:35<18:32,  2.31s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/cjg8h12k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/9eper205.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72301', 'data', 'file=/tmp/tmp5oal43fk/cjg8h12k.json', 'init=/tmp/tmp5oal43fk/9eper205.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelvt5kyr24/prophet_model-20221015095839.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3269/3750 [2:34:35<14:12,  1.77s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/e_5fl2bg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/luowjv9e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85588', 'data', 'file=/tmp/tmp5oal43fk/e_5fl2bg.json', 'init=/tmp/tmp5oal43fk/luowjv9e.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelbopjlspq/prophet_model-20221015095840.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3270/3750 [2:34:39<19:24,  2.43s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/aa0s9v9f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/i_jm1vyn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26578', 'data', 'file=/tmp/tmp5oal43fk/aa0s9v9f.json', 'init=/tmp/tmp5oal43fk/i_jm1vyn.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelq661932c/prophet_model-20221015095843.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3271/3750 [2:34:40<14:42,  1.84s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/vgbe3olk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/54xrbdlt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95304', 'data', 'file=/tmp/tmp5oal43fk/vgbe3olk.json', 'init=/tmp/tmp5oal43fk/54xrbdlt.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model9ckn_r31/prophet_model-20221015095844.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3272/3750 [2:34:44<20:07,  2.53s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/j6ld8oy1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/9dkgopom.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72382', 'data', 'file=/tmp/tmp5oal43fk/j6ld8oy1.json', 'init=/tmp/tmp5oal43fk/9dkgopom.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelrslo95we/prophet_model-20221015095848.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3273/3750 [2:34:44<15:32,  1.95s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/beddtz5m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/w7jx6zmv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27525', 'data', 'file=/tmp/tmp5oal43fk/beddtz5m.json', 'init=/tmp/tmp5oal43fk/w7jx6zmv.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelc3_q6wrq/prophet_model-20221015095849.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3274/3750 [2:34:48<18:58,  2.39s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/u93wr0n1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/r_pth9f6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25258', 'data', 'file=/tmp/tmp5oal43fk/u93wr0n1.json', 'init=/tmp/tmp5oal43fk/r_pth9f6.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeljttpmka7/prophet_model-20221015095852.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3275/3750 [2:34:49<15:21,  1.94s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/8d_lqbxj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/vnn1gutw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54416', 'data', 'file=/tmp/tmp5oal43fk/8d_lqbxj.json', 'init=/tmp/tmp5oal43fk/vnn1gutw.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model4kk4s_k8/prophet_model-20221015095853.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:58:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3276/3750 [2:34:52<18:01,  2.28s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/tdnd4gwo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/diqf2y2r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89273', 'data', 'file=/tmp/tmp5oal43fk/tdnd4gwo.json', 'init=/tmp/tmp5oal43fk/diqf2y2r.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelv_scn1k1/prophet_model-20221015095856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  87%|████████▋ | 3277/3750 [2:34:53<15:06,  1.92s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/pv10mgna.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/kf4w7j_a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50300', 'data', 'file=/tmp/tmp5oal43fk/pv10mgna.json', 'init=/tmp/tmp5oal43fk/kf4w7j_a.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeltmdhfovf/prophet_model-20221015095857.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:58:57 - cmdstanpy - INFO - Chain [1] start processing
# 09:58:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:58:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3278/3750 [2:34:56<17:52,  2.27s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/lky9totk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/oy9_fl3t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2214', 'data', 'file=/tmp/tmp5oal43fk/lky9totk.json', 'init=/tmp/tmp5oal43fk/oy9_fl3t.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelpig7mj2h/prophet_model-20221015095900.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3279/3750 [2:34:58<17:13,  2.20s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/5alpyve7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/1x1f_e7l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86193', 'data', 'file=/tmp/tmp5oal43fk/5alpyve7.json', 'init=/tmp/tmp5oal43fk/1x1f_e7l.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model6lf2_f6_/prophet_model-20221015095902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3280/3750 [2:35:00<18:04,  2.31s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/k3a7zwwa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/waoyjuhw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23636', 'data', 'file=/tmp/tmp5oal43fk/k3a7zwwa.json', 'init=/tmp/tmp5oal43fk/waoyjuhw.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelfj4l5v7n/prophet_model-20221015095905.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  87%|████████▋ | 3281/3750 [2:35:02<16:06,  2.06s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/lqf3jom3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/ckxe014q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12675', 'data', 'file=/tmp/tmp5oal43fk/lqf3jom3.json', 'init=/tmp/tmp5oal43fk/ckxe014q.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeli7qibgo7/prophet_model-20221015095906.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3282/3750 [2:35:04<16:01,  2.05s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/hq9n5gb2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/n8r0da48.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8152', 'data', 'file=/tmp/tmp5oal43fk/hq9n5gb2.json', 'init=/tmp/tmp5oal43fk/n8r0da48.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeltyj87y95/prophet_model-20221015095908.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3283/3750 [2:35:06<15:03,  1.94s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/8vm_ns5f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/wteype6c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20403', 'data', 'file=/tmp/tmp5oal43fk/8vm_ns5f.json', 'init=/tmp/tmp5oal43fk/wteype6c.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modellz89pf2u/prophet_model-20221015095910.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3284/3750 [2:35:08<16:06,  2.07s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/r5gnvwsn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/m4657ta0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73404', 'data', 'file=/tmp/tmp5oal43fk/r5gnvwsn.json', 'init=/tmp/tmp5oal43fk/m4657ta0.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelpq1ah7kp/prophet_model-20221015095912.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3285/3750 [2:35:10<16:29,  2.13s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/yk80fxu7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/6157bgoh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39670', 'data', 'file=/tmp/tmp5oal43fk/yk80fxu7.json', 'init=/tmp/tmp5oal43fk/6157bgoh.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modeluzmm3kgs/prophet_model-20221015095915.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3286/3750 [2:35:12<16:34,  2.14s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/7_rdti9k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/5zt919bw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29557', 'data', 'file=/tmp/tmp5oal43fk/7_rdti9k.json', 'init=/tmp/tmp5oal43fk/5zt919bw.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelnzwoj91r/prophet_model-20221015095917.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3287/3750 [2:35:15<17:47,  2.31s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/bqtc9otc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/ay2e2vbi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75575', 'data', 'file=/tmp/tmp5oal43fk/bqtc9otc.json', 'init=/tmp/tmp5oal43fk/ay2e2vbi.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelbwywlmge/prophet_model-20221015095920.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3288/3750 [2:35:17<16:54,  2.20s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/iysy96a9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/x3bepay3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18919', 'data', 'file=/tmp/tmp5oal43fk/iysy96a9.json', 'init=/tmp/tmp5oal43fk/x3bepay3.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelabk43_ox/prophet_model-20221015095921.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3289/3750 [2:35:19<16:53,  2.20s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/2mlg8i3n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/zy4rtzdm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12937', 'data', 'file=/tmp/tmp5oal43fk/2mlg8i3n.json', 'init=/tmp/tmp5oal43fk/zy4rtzdm.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelt_y1k7zw/prophet_model-20221015095924.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3290/3750 [2:35:21<16:30,  2.15s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/k1kwsh58.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/bftqzzlo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60803', 'data', 'file=/tmp/tmp5oal43fk/k1kwsh58.json', 'init=/tmp/tmp5oal43fk/bftqzzlo.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model4f5a3k3z/prophet_model-20221015095926.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3291/3750 [2:35:23<16:02,  2.10s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/0aph6p9c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/1fjdo505.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=948', 'data', 'file=/tmp/tmp5oal43fk/0aph6p9c.json', 'init=/tmp/tmp5oal43fk/1fjdo505.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelss0qijnc/prophet_model-20221015095928.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3292/3750 [2:35:26<16:23,  2.15s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/ibz101sx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/yyy11sey.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73704', 'data', 'file=/tmp/tmp5oal43fk/ibz101sx.json', 'init=/tmp/tmp5oal43fk/yyy11sey.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelry8xuh17/prophet_model-20221015095930.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  88%|████████▊ | 3293/3750 [2:35:27<14:41,  1.93s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/hbo42sdp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/53byoc6b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 09:59:31 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79398', 'data', 'file=/tmp/tmp5oal43fk/hbo42sdp.json', 'init=/tmp/tmp5oal43fk/53byoc6b.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelimmlzn91/prophet_model-20221015095931.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] done processing
# 09:59:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3294/3750 [2:35:30<17:12,  2.26s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/8n4czyaw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/6hk3ise6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42642', 'data', 'file=/tmp/tmp5oal43fk/8n4czyaw.json', 'init=/tmp/tmp5oal43fk/6hk3ise6.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelrp9n8sw0/prophet_model-20221015095934.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  88%|████████▊ | 3295/3750 [2:35:32<16:04,  2.12s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/gos8ccc5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/s74p2erm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56632', 'data', 'file=/tmp/tmp5oal43fk/gos8ccc5.json', 'init=/tmp/tmp5oal43fk/s74p2erm.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelirrm_6_y/prophet_model-20221015095936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:59:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3296/3750 [2:35:35<18:42,  2.47s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/mryn6cle.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/u0v0rv37.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62638', 'data', 'file=/tmp/tmp5oal43fk/mryn6cle.json', 'init=/tmp/tmp5oal43fk/u0v0rv37.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelrhm3rrfx/prophet_model-20221015095939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3297/3750 [2:35:37<17:51,  2.37s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/otf8tbzi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/4nbrasc2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42565', 'data', 'file=/tmp/tmp5oal43fk/otf8tbzi.json', 'init=/tmp/tmp5oal43fk/4nbrasc2.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model56e2s9hr/prophet_model-20221015095942.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3298/3750 [2:35:39<16:36,  2.20s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/52mcyty9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/d1yyabwi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45278', 'data', 'file=/tmp/tmp5oal43fk/52mcyty9.json', 'init=/tmp/tmp5oal43fk/d1yyabwi.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model7klgzlmr/prophet_model-20221015095943.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3299/3750 [2:35:41<16:21,  2.18s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/dum9yo33.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/p8n4u38_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5078', 'data', 'file=/tmp/tmp5oal43fk/dum9yo33.json', 'init=/tmp/tmp5oal43fk/p8n4u38_.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelnwvzx3th/prophet_model-20221015095946.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#  88%|████████▊ | 3300/3750 [2:35:43<16:00,  2.14s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/cw531ve2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/vum3s1hd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63568', 'data', 'file=/tmp/tmp5oal43fk/cw531ve2.json', 'init=/tmp/tmp5oal43fk/vum3s1hd.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelv1ezisnm/prophet_model-20221015095948.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:59:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:59:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  88%|████████▊ | 3301/3750 [2:35:47<18:45,  2.51s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/axg2nybr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/325bmctm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51002', 'data', 'file=/tmp/tmp5oal43fk/axg2nybr.json', 'init=/tmp/tmp5oal43fk/325bmctm.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model3ohvvtl3/prophet_model-20221015095951.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:59:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ...
# 10:15:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 100%|█████████▉| 3732/3750 [2:51:33<00:36,  2.04s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/zjz4ntxe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/yz1huj7m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61574', 'data', 'file=/tmp/tmp5oal43fk/zjz4ntxe.json', 'init=/tmp/tmp5oal43fk/yz1huj7m.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelfte1v54z/prophet_model-20221015101537.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:15:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:15:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3733/3750 [2:51:36<00:42,  2.49s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/yv8evlzb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/l51048gc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6966', 'data', 'file=/tmp/tmp5oal43fk/yv8evlzb.json', 'init=/tmp/tmp5oal43fk/l51048gc.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelu781bton/prophet_model-20221015101541.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 100%|█████████▉| 3734/3750 [2:51:37<00:30,  1.92s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/gy2__69b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/t0_d01b3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21366', 'data', 'file=/tmp/tmp5oal43fk/gy2__69b.json', 'init=/tmp/tmp5oal43fk/t0_d01b3.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelp283_weq/prophet_model-20221015101541.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:15:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:15:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3735/3750 [2:51:41<00:38,  2.56s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/4qn6bpyc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/xew792ft.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68066', 'data', 'file=/tmp/tmp5oal43fk/4qn6bpyc.json', 'init=/tmp/tmp5oal43fk/xew792ft.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelc3jm_b57/prophet_model-20221015101545.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 100%|█████████▉| 3736/3750 [2:51:41<00:27,  1.93s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/uxf0ksfm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/f06y7oyl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12279', 'data', 'file=/tmp/tmp5oal43fk/uxf0ksfm.json', 'init=/tmp/tmp5oal43fk/f06y7oyl.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelu3k7m3m5/prophet_model-20221015101546.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:15:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:15:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3737/3750 [2:51:45<00:31,  2.41s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/9hpvimi8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/6wzso3x1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88977', 'data', 'file=/tmp/tmp5oal43fk/9hpvimi8.json', 'init=/tmp/tmp5oal43fk/6wzso3x1.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model9uwb8ca8/prophet_model-20221015101549.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 100%|█████████▉| 3738/3750 [2:51:45<00:21,  1.83s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/v8d2tsfc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/zzo_n3s5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68257', 'data', 'file=/tmp/tmp5oal43fk/v8d2tsfc.json', 'init=/tmp/tmp5oal43fk/zzo_n3s5.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model4770e6a5/prophet_model-20221015101550.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:15:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:15:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3739/3750 [2:51:49<00:26,  2.38s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/8tjhqnwh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/63i4n597.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20701', 'data', 'file=/tmp/tmp5oal43fk/8tjhqnwh.json', 'init=/tmp/tmp5oal43fk/63i4n597.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model8s7jk77q/prophet_model-20221015101553.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 100%|█████████▉| 3740/3750 [2:51:50<00:18,  1.85s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/to8x2hft.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/4jpand5q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90556', 'data', 'file=/tmp/tmp5oal43fk/to8x2hft.json', 'init=/tmp/tmp5oal43fk/4jpand5q.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelyscbb4tu/prophet_model-20221015101554.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:15:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:15:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3741/3750 [2:51:53<00:20,  2.29s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/e8foxpvm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/5omd2q7k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86161', 'data', 'file=/tmp/tmp5oal43fk/e8foxpvm.json', 'init=/tmp/tmp5oal43fk/5omd2q7k.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modely0joa9wo/prophet_model-20221015101557.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:15:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3742/3750 [2:51:54<00:16,  2.02s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/2wh6mpem.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/30zare5y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63456', 'data', 'file=/tmp/tmp5oal43fk/2wh6mpem.json', 'init=/tmp/tmp5oal43fk/30zare5y.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model8amrqrs6/prophet_model-20221015101559.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:15:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:16:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3743/3750 [2:51:57<00:14,  2.13s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/hbtcnu6x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/kuazeut4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12479', 'data', 'file=/tmp/tmp5oal43fk/hbtcnu6x.json', 'init=/tmp/tmp5oal43fk/kuazeut4.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelrsn19qww/prophet_model-20221015101601.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:16:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 100%|█████████▉| 3744/3750 [2:51:58<00:11,  1.95s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/sz24z04k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/bqx6mupi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28198', 'data', 'file=/tmp/tmp5oal43fk/sz24z04k.json', 'init=/tmp/tmp5oal43fk/bqx6mupi.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model9mcc2ur0/prophet_model-20221015101603.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:16:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:16:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:16:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|█████████▉| 3745/3750 [2:52:02<00:12,  2.60s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/h71p1rbz.json
# 100%|█████████▉| 3746/3750 [2:52:03<00:07,  1.90s/it]INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/6dz6hp9u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59202', 'data', 'file=/tmp/tmp5oal43fk/h71p1rbz.json', 'init=/tmp/tmp5oal43fk/6dz6hp9u.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelpi0hpdo7/prophet_model-20221015101607.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:16:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/04rfvcbe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/xjw34ee9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54344', 'data', 'file=/tmp/tmp5oal43fk/04rfvcbe.json', 'init=/tmp/tmp5oal43fk/xjw34ee9.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelbz2pyox3/prophet_model-20221015101607.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:16:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:16:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:16:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 100%|█████████▉| 3747/3750 [2:52:07<00:07,  2.53s/it]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/5b9ajc1c.json
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/q47n70yp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3952', 'data', 'file=/tmp/tmp5oal43fk/5b9ajc1c.json', 'init=/tmp/tmp5oal43fk/q47n70yp.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_model5xs8gmzy/prophet_model-20221015101611.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:16:11 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/zzsr4xxq.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5oal43fk/s3ou_05x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45551', 'data', 'file=/tmp/tmp5oal43fk/zzsr4xxq.json', 'init=/tmp/tmp5oal43fk/s3ou_05x.json', 'output', 'file=/tmp/tmp5oal43fk/prophet_modelgd66rncg/prophet_model-20221015101611.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:16:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:16:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:16:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|██████████| 3750/3750 [2:52:11<00:00,  2.76s/it]

# %% [markdown]
# Thank you for patiently scrolling! 👵🏻

# %%
type(multiprocess_forecast)
# Out:
# pandas.core.frame.DataFrame

# %%
multiprocess_forecast.head(5)
# Out:
#           ds star_id       yhat  yhat_upper  yhat_lower
# 0 2016-08-15       1 -13.755567  119.634607 -162.458141
# 1 2016-08-16       1 -13.441980  127.379265 -152.266148
# 2 2016-08-17       1 -13.637111  124.952621 -145.475576
# 3 2016-08-18       1 -13.917658  122.046222 -150.452084
# 4 2016-08-19       1 -13.820799  125.450520 -158.616738

# %% [markdown]
# ***Exploring forecasted predictions***

# %%
(multiprocess_forecast['star_id']).unique()
# Out:
# array(['1', '2', '3', ..., '4997', '4998', '4999'], dtype=object)

# %%
star_1_forecast = multiprocess_forecast.loc[(multiprocess_forecast['star_id'] == '1')]

# %% [markdown]
# ***Converting the arbitrary date-time values back to 'FLUX.XXXX' values***

# %%
star_1_forecast['row_1'] = 'FLUX.'

star_1_forecast['row_2'] = range(1, len(star_1_forecast) + 1)
star_1_forecast['row_2'] = star_1_forecast['row_2'].astype('str')

star_1_forecast['flux'] = star_1_forecast['row_1'] + star_1_forecast['row_2']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_1_forecast.drop(['ds', 'row_1', 'row_2'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
star_1_forecast.head(5)
# Out:
#   star_id       yhat  yhat_upper  yhat_lower    flux
# 0       1 -13.755567  119.634607 -162.458141  FLUX.1
# 1       1 -13.441980  127.379265 -152.266148  FLUX.2
# 2       1 -13.637111  124.952621 -145.475576  FLUX.3
# 3       1 -13.917658  122.046222 -150.452084  FLUX.4
# 4       1 -13.820799  125.450520 -158.616738  FLUX.5

# %%
star_1_forecast.star_id.unique()
# Out:
# array(['1'], dtype=object)

# %% [markdown]
# ***Plotting Prophet's future flux values of star 1***

# %%
import plotly.graph_objects as px
import numpy as np

plot = px.Figure(data=[px.Scatter(
	x=star_1_forecast['flux'],
	y=star_1_forecast['yhat'], 
	line=dict(color="darkturquoise"),
	mode='lines',)
])

plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1c41cdac-3db7-4d1a-a1b4-672bc9038e29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c41cdac-3db7-4d1a-a1b4-672bc9038e29")) {                    Plotly.newPlot(                        "1c41cdac-3db7-4d1a-a1b4-672bc9038e29",                        [{"line":{"color":"darkturquoise"},"mode":"lines","x":["FLUX.1","FLUX.2","FLUX.3","FLUX.4","FLUX.5","FLUX.6","FLUX.7","FLUX.8","FLUX.9","FLUX.10","FLUX.11","FLUX.12","FLUX.13","FLUX.14","FLUX.15","FLUX.16","FLUX.17","FLUX.18","FLUX.19","FLUX.20","FLUX.21","FLUX.22","FLUX.23","FLUX.24","FLUX.25","FLUX.26","FLUX.27","FLUX.28","FLUX.29","FLUX.30","FLUX.31","FLUX.32","FLUX.33","FLUX.34","FLUX.35","FLUX.36","FLUX.37","FLUX.38","FLUX.39","FLUX.40","FLUX.41","FLUX.42","FLUX.43","FLUX.44","FLUX.45","FLUX.46","FLUX.47","FLUX.48","FLUX.49","FLUX.50","FLUX.51","FLUX.52","FLUX.53","FLUX.54","FLUX.55","FLUX.56","FLUX.57","FLUX.58","FLUX.59","FLUX.60","FLUX.61","FLUX.62","FLUX.63","FLUX.64","FLUX.65","FLUX.66","FLUX.67","FLUX.68","FLUX.69","FLUX.70","FLUX.71","FLUX.72","FLUX.73","FLUX.74","FLUX.75","FLUX.76","FLUX.77","FLUX.78","FLUX.79","FLUX.80","FLUX.81","FLUX.82","FLUX.83","FLUX.84","FLUX.85","FLUX.86","FLUX.87","FLUX.88","FLUX.89","FLUX.90","FLUX.91","FLUX.92","FLUX.93","FLUX.94","FLUX.95","FLUX.96","FLUX.97","FLUX.98","FLUX.99","FLUX.100","FLUX.101","FLUX.102","FLUX.103","FLUX.104","FLUX.105","FLUX.106","FLUX.107","FLUX.108","FLUX.109","FLUX.110","FLUX.111","FLUX.112","FLUX.113","FLUX.114","FLUX.115","FLUX.116","FLUX.117","FLUX.118","FLUX.119","FLUX.120","FLUX.121","FLUX.122","FLUX.123","FLUX.124","FLUX.125","FLUX.126","FLUX.127","FLUX.128","FLUX.129","FLUX.130","FLUX.131","FLUX.132","FLUX.133","FLUX.134","FLUX.135","FLUX.136","FLUX.137","FLUX.138","FLUX.139","FLUX.140","FLUX.141","FLUX.142","FLUX.143","FLUX.144","FLUX.145","FLUX.146","FLUX.147","FLUX.148","FLUX.149","FLUX.150","FLUX.151","FLUX.152","FLUX.153","FLUX.154","FLUX.155","FLUX.156","FLUX.157","FLUX.158","FLUX.159","FLUX.160","FLUX.161","FLUX.162","FLUX.163","FLUX.164","FLUX.165","FLUX.166","FLUX.167","FLUX.168","FLUX.169","FLUX.170","FLUX.171","FLUX.172","FLUX.173","FLUX.174","FLUX.175","FLUX.176","FLUX.177","FLUX.178","FLUX.179","FLUX.180","FLUX.181","FLUX.182","FLUX.183","FLUX.184","FLUX.185","FLUX.186","FLUX.187","FLUX.188","FLUX.189","FLUX.190","FLUX.191","FLUX.192","FLUX.193","FLUX.194","FLUX.195","FLUX.196","FLUX.197","FLUX.198","FLUX.199","FLUX.200","FLUX.201","FLUX.202","FLUX.203","FLUX.204","FLUX.205","FLUX.206","FLUX.207","FLUX.208","FLUX.209","FLUX.210","FLUX.211","FLUX.212","FLUX.213","FLUX.214","FLUX.215","FLUX.216","FLUX.217","FLUX.218","FLUX.219","FLUX.220","FLUX.221","FLUX.222","FLUX.223","FLUX.224","FLUX.225","FLUX.226","FLUX.227","FLUX.228","FLUX.229","FLUX.230","FLUX.231","FLUX.232","FLUX.233","FLUX.234","FLUX.235","FLUX.236","FLUX.237","FLUX.238","FLUX.239","FLUX.240","FLUX.241","FLUX.242","FLUX.243","FLUX.244","FLUX.245","FLUX.246","FLUX.247","FLUX.248","FLUX.249","FLUX.250","FLUX.251","FLUX.252","FLUX.253","FLUX.254","FLUX.255","FLUX.256","FLUX.257","FLUX.258","FLUX.259","FLUX.260","FLUX.261","FLUX.262","FLUX.263","FLUX.264","FLUX.265","FLUX.266","FLUX.267","FLUX.268","FLUX.269","FLUX.270","FLUX.271","FLUX.272","FLUX.273","FLUX.274","FLUX.275","FLUX.276","FLUX.277","FLUX.278","FLUX.279","FLUX.280","FLUX.281","FLUX.282","FLUX.283","FLUX.284","FLUX.285","FLUX.286","FLUX.287","FLUX.288","FLUX.289","FLUX.290","FLUX.291","FLUX.292","FLUX.293","FLUX.294","FLUX.295","FLUX.296","FLUX.297","FLUX.298","FLUX.299","FLUX.300","FLUX.301","FLUX.302","FLUX.303","FLUX.304","FLUX.305","FLUX.306","FLUX.307","FLUX.308","FLUX.309","FLUX.310","FLUX.311","FLUX.312","FLUX.313","FLUX.314","FLUX.315","FLUX.316","FLUX.317","FLUX.318","FLUX.319 ...
